# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

path_csv = ('/Users/jeong/Documents/OPERA_SCRATCH/CSLC/FLATTENING_COMARISON/'
            'output_s1_cslc_without_flattening/t064_135523_iw2/20221016/'
            't064_135523_iw2_20221016.h5.CRs.mm24.csv')

# %%
df = pd.read_csv(path_csv)

ALE = ALE = np.sqrt(df['ALE_X']**2 + df['ALE_Y']**2)
plt.plot(df['CR_SNR_PEAK'], ALE,'.')
plt.xlabel('SNR (dB)')
plt.ylabel('AGE (m)')
plt.grid(True)
#for i, t in enumerate('Corner reflector ID'):
#    plt.text(df['CR_SNR_PEAK'][i], ALE[i], t)
